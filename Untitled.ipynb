# %%
from pyspark.sql import SparkSession
from pyspark.sql.types import *
from pyspark.sql.functions import *

# %%
spark=SparkSession.builder.appName('Stark').getOrCreate()
# Out:
# 23/12/11 18:48:42 WARN SparkSession: Using an existing Spark session; only runtime SQL configurations will take effect.

# %%
schema=StructType([
    StructField('fullVisitors', IntegerType(), True),
    StructField('Channel',StringType(), True), 
    StructField('time', IntegerType(), True), 
    StructField('country', StringType(), True), 
    StructField('city', StringType(), True),
    StructField('timeOnsite', IntegerType(), True), 
    StructField('pageviews', IntegerType(), True), 
    StructField('date', IntegerType(), True),
    StructField('vistId', StringType(), True), 
    StructField('type', StringType(), True), 
    StructField('productprice', IntegerType(), True),
    StructField('Ptype', StringType(), True), 
    StructField('path', StringType(), True), 
    StructField('channelpath', StringType(), True)
    
])

# %%
data=spark.read.csv('/user/stark/ecomdata.csv',schema=schema)

# %%
data.show()
# Out:
# +------------+--------------+-------+--------------+--------------------+----------+---------+--------+----------+-----+------------+--------------------+--------------------+-----------+
# |fullVisitors|       Channel|   time|       country|                city|timeOnsite|pageviews|    date|    vistId| type|productprice|               Ptype|                path|channelpath|
# +------------+--------------+-------+--------------+--------------------+----------+---------+--------+----------+-----+------------+--------------------+--------------------+-----------+
# |        null|        Direct|  63131| United States|            New York|       117|        9|20160822|1471898479| PAGE|    16990000|Women's YouTube S...|Home/Shop by Bran...|    YouTube|
# |        null|        Direct|  15249|        Taiwan|not available in ...|        73|        4|20160909|1473433346| PAGE|    16990000|Women's YouTube S...|Home/Shop by Bran...|    YouTube|
# |        null|        Social| 262937|       Czechia|not available in ...|       325|       12|20160828|1472389533| PAGE|    16990000|Women's YouTube S...|Home/Shop by Bran...|    YouTube|
# |        null|Organic Search|1727433|        Mexico|not available in ...|      3252|       20|20160916|1474047024| PAGE|    16990000|Women's YouTube S...|Home/Shop by Bran...|    YouTube|
# |        null|Organic Search|1112098|     Venezuela|           Maracaibo|     10076|      351|20160825|1472172400| PAGE|    16990000|Women's YouTube S...|Home/Shop by Bran...|    YouTube|
# |        null|Organic Search| 788334| United States|           Ann Arbor|       874|       20|20160824|1472056557| PAGE|    16990000|Women's YouTube S...|Home/Shop by Bran...|    YouTube|
# |        null|Organic Search|   7040| United States|            New York|       645|       20|20160829|1472478374| PAGE|    16990000|Women's YouTube S...|Home/Shop by Bran...|    YouTube|
# |        null|        Direct|  15256|         Japan|not available in ...|        15|        2|20160907|1473255670| PAGE|    16990000|Women's YouTube S...|Home/Shop by Bran...|    YouTube|
# |        null|        Social|  52536|        Taiwan|not available in ...|       202|        6|20160929|1475155332| PAGE|    16990000|Women's YouTube S...|Home/Shop by Bran...|    YouTube|
# |        null|        Social|  46734|     (not set)|           (not set)|        84|        3|20161004|1475593638| PAGE|    18990000|YouTube Men's Sho...|Home/Shop by Bran...|    YouTube|
# |        null|Organic Search| 837974| United States|         Los Angeles|      1908|       66|20160905|1473120978| PAGE|    18990000|YouTube Men's Sho...|Home/Shop by Bran...|    YouTube|
# |        null|Organic Search|  28867|     Australia|            Brisbane|       386|       14|20160915|1473977891| PAGE|    18990000|YouTube Men's Sho...|Home/Shop by Bran...|    YouTube|
# |        null|        Social|  17517|United Kingdom|not available in ...|        18|        2|20160917|1474110566| PAGE|    18990000|YouTube Men's Sho...|Home/Shop by Bran...|    YouTube|
# |        null|Organic Search|  16722| United States|not available in ...|        97|       14|20161006|1475802784|EVENT|    18990000|YouTube Men's Sho...|Home/Shop by Bran...|    YouTube|
# |        null|        Social| 114170|         India|not available in ...|       138|        4|20160909|1473415123| PAGE|    18990000|YouTube Men's Sho...|Home/Shop by Bran...|    YouTube|
# |        null|Organic Search|      0|   New Zealand|not available in ...|       283|        6|20160905|1473059081| PAGE|    18990000|YouTube Men's Sho...|Home/Shop by Bran...|    YouTube|
# |        null|      Referral|  73001| United States|not available in ...|      1003|       18|20160907|1473261575| PAGE|    18990000|YouTube Men's Sho...|Home/Shop by Bran...|    YouTube|
# |        null|Organic Search|1210026|        Canada|not available in ...|      1372|       25|20160905|1473110825| PAGE|    18990000|YouTube Men's Sho...|Home/Shop by Bran...|    YouTube|
# |        null|Organic Search| 106138|United Kingdom|not available in ...|       123|        6|20160827|1472337998| PAGE|    18990000|YouTube Men's Sho...|Home/Shop by Bran...|    YouTube|
# |        null|Organic Search|      0| United States|not available in ...|         0|        1|20161001|1475382910| PAGE|    18990000|YouTube Men's Sho...|Home/Shop by Bran...|    YouTube|
# +------------+--------------+-------+--------------+--------------------+----------+---------+--------+----------+-----+------------+--------------------+--------------------+-----------+
# only showing top 20 rows

# %%
import matplotlib.pyplot as plt

# %%
panda_data=data.toPandas()

# %%
plt.bar(panda_data['time'],panda_data['timeOnsite'])
plt.xlabel('time')
plt.ylabel('timeOnsite')
plt.title('barGraph')
plt.show()

# %%
plt.bar(panda_data['productprice'],panda_data['Ptype'])
plt.xlabel('productprice')
plt.ylabel('Ptype')
plt.title('barGraph')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_11360/2836748208.py in <cell line: 1>()
# ----> 1 plt.bar(panda_data['productprice'],panda_data['Ptype'],bins=10)
#       2 plt.xlabel('productprice')
#       3 plt.ylabel('Ptype')
#       4 plt.title('barGraph')
#       5 plt.show()
#
# /opt/conda/miniconda3/lib/python3.10/site-packages/matplotlib/pyplot.py in bar(x, height, width, bottom, align, data, **kwargs)
#    2395         x, height, width=0.8, bottom=None, *, align='center',
#    2396         data=None, **kwargs):
# -> 2397     return gca().bar(
#    2398         x, height, width=width, bottom=bottom, align=align,
#    2399         **({"data": data} if data is not None else {}), **kwargs)
#
# /opt/conda/miniconda3/lib/python3.10/site-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1412     def inner(ax, *args, data=None, **kwargs):
#    1413         if data is None:
# -> 1414             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1415
#    1416         bound = new_sig.bind(ax, *args, **kwargs)
#
# /opt/conda/miniconda3/lib/python3.10/site-packages/matplotlib/axes/_axes.py in bar(self, x, height, width, bottom, align, **kwargs)
#    2404                 hatch=htch,
#    2405                 )
# -> 2406             r.update(kwargs)
#    2407             r.get_path()._interpolation_steps = 100
#    2408             if orientation == 'vertical':
#
# /opt/conda/miniconda3/lib/python3.10/site-packages/matplotlib/artist.py in update(self, props)
#    1065                     func = getattr(self, f"set_{k}", None)
#    1066                     if not callable(func):
# -> 1067                         raise AttributeError(f"{type(self).__name__!r} object "
#    1068                                              f"has no property {k!r}")
#    1069                     ret.append(func(v))
#
# AttributeError: 'Rectangle' object has no property 'bins'

# %%
plt.hist(panda_data['productprice'],bins=10, edgecolor='red')
plt.xlabel('Ptype')
plt.ylabel('productprice')
plt.title('histGraph')
plt.show()

# %%
import seaborn as sns

# %%
sns.boxplot(x='productprice',data=panda_data)
plt.title('boxplot')
plt.show()
